# %% [markdown]
# # This notebook is downloaded from Google colab. DO NOT RUN IT! The results will be gone otherwise.

# %%
import glob
import pickle
import numpy as np
import os
from music21 import converter, instrument, note, chord, stream
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM, CuDNNLSTM
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Step 0: Use google colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
notes = np.load('/content/gdrive/My Drive/notes.npy') #Get file preprocessed in MIDI Preprocessing.ipynb

# %% [markdown]
# ## Step 1: Preprocess data

# %%
pitchnames = sorted(list(set(notes)))
data_size, vocab_size = len(notes), len(pitchnames)
print('data has %d notes, %d unique pitches.' % (data_size, vocab_size))
# Out:
# data has 254731 notes, 286 unique pitches.

# %%
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

# %% [markdown]
# ### All the way up to here, every step is the same as what I did in the ABC.ipynb notebook

# %%
seq_len = 100
dataX=[]
dataY=[]
for i in range(0, len(notes) - seq_len, 1):
    x = notes[i:i + seq_len]
    y = notes[i + seq_len]        
    dataX.append([note_to_int[char] for char in x])
    dataY.append(note_to_int[y])
n_patterns = len(dataX)
print("Total Patterns: ", n_patterns)

# %% [markdown]
# This time, I'm doing a many-to-one LSTM: using 100 notes to predict the next one.

# %%
# reshape X to be [samples, time steps, features]
X = np.reshape(dataX, (n_patterns, seq_len, 1))
# normalize
X = X / float(vocab_size)
# one hot encode the output variable
y = np_utils.to_categorical(dataY)

# %% [markdown]
# ## Step 2: build the model

# %%
model = Sequential()
model.add(LSTM(
        512,
        input_shape=(X.shape[1], X.shape[2]),
        recurrent_dropout=0.3,
        return_sequences=True
    ))
model.add(CuDNNLSTM(512, return_sequences=True))
model.add(Dropout(0.3))
model.add(CuDNNLSTM(512))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(vocab_size))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100, 512)          1052672
# _________________________________________________________________
# cu_dnnlstm_1 (CuDNNLSTM)     (None, 100, 512)          2101248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 512)          0
# _________________________________________________________________
# cu_dnnlstm_2 (CuDNNLSTM)     (None, 512)               2101248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 286)               73502
# _________________________________________________________________
# activation_2 (Activation)    (None, 286)               0
# =================================================================
# Total params: 5,463,070
# Trainable params: 5,461,534
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# ## Step 3: train the model and generate MIDI format music along the way

# %%
from keras.callbacks import *
filepath="/content/gdrive/My Drive/acc:{acc:.3f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %% [markdown]
# This is the callbacks part I talked about in my blog. It's very important to train and save the model simaltaneously especially when the model is trained intermittently.

# %%
def generate_notes(model, epoch):
    start = np.random.randint(0, len(dataX)-1)
    pattern = dataX[start]
    print ("Seed:")
    print ("\"", ''.join([int_to_note[value] for value in pattern]), "\"")
    output = []
# generate 1000 characters 1 by 1
    for i in range(1000):
        x = np.reshape(pattern, (1, len(pattern), 1))
        x = x / float(vocab_size)
        prediction = model.predict(x, verbose=0)
        index = np.argmax(prediction)
        result = int_to_note[index]
        
        output.append(result)
        
        pattern.append(index) # the previous output is now appended to the input to predict the next one
        pattern = pattern[1:len(pattern)]
        
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in output:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes) #create score
    midi_file_name = ('/content/gdrive/My Drive/lstm_out_{}.mid'.format(epoch)) #write the score to midi
    midi_stream.write('midi', fp=midi_file_name)

   

    return ("\nDone.")

# %%
Epoch = 0
while Epoch <= 30:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch) #generate a piece of music every 10 epochs
    Epoch+=1
# Out:
# 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 254631/254631 [==============================] - 400s 2ms/step - loss: 4.6353 - acc: 0.0233
#
# Epoch 00001: acc improved from -inf to 0.02331, saving model to /content/gdrive/My Drive/acc:0.023.hdf5
# Seed:
# " C3D3E3F3C55.8.0G3G#3C510.0.4G3F3C510.0.4E3C#3C510.0.4C3B-2C510.0.4G#2G2C59.0.36A3C4E-4F#4A4C5E-5F#5A5C6E-6F#6E-6C6A5F#5E-5C5A4F#4E-4C4A3F#3E-3C3A2F#2E-2C2A1G#1A1C2E-2G#1A1C2E-2G#1A1C2E-28.9A1C2E-2F1A3C4E-4F#4G#4F#4F4E-4F4E-4C#4C4C#4E-4C4F2A3F1C4E-4F#4G#4F#4F4E-4 "
#
#
#
# 1
# Epoch 1/1
# 254631/254631 [==============================] - 390s 2ms/step - loss: 4.4390 - acc: 0.0268
#
# Epoch 00001: acc improved from 0.02331 to 0.02676, saving model to /content/gdrive/My Drive/acc:0.027.hdf5
#
#
#
# 2
# Epoch 1/1
# 254631/254631 [==============================] - 390s 2ms/step - loss: 4.4038 - acc: 0.0279
#
# Epoch 00001: acc improved from 0.02676 to 0.02787, saving model to /content/gdrive/My Drive/acc:0.028.hdf5
#
#
#
# 3
# Epoch 1/1
# 254631/254631 [==============================] - 391s 2ms/step - loss: 4.3982 - acc: 0.0274
#
# Epoch 00001: acc did not improve from 0.02787
#
#
#
# 4
# Epoch 1/1
# 254631/254631 [==============================] - 395s 2ms/step - loss: 4.3865 - acc: 0.0279
#
# Epoch 00001: acc improved from 0.02787 to 0.02793, saving model to /content/gdrive/My Drive/acc:0.028.hdf5
#
#
#
# 5
# Epoch 1/1
# 254631/254631 [==============================] - 397s 2ms/step - loss: 4.3196 - acc: 0.0309
#
# Epoch 00001: acc improved from 0.02793 to 0.03088, saving model to /content/gdrive/My Drive/acc:0.031.hdf5
#
#
#
# 6
# Epoch 1/1
# 254631/254631 [==============================] - 396s 2ms/step - loss: 4.2717 - acc: 0.0351
#
# Epoch 00001: acc improved from 0.03088 to 0.03507, saving model to /content/gdrive/My Drive/acc:0.035.hdf5
#
#
#
# 7
# Epoch 1/1
# 254631/254631 [==============================] - 396s 2ms/step - loss: 4.2270 - acc: 0.0408
#
# Epoch 00001: acc improved from 0.03507 to 0.04076, saving model to /content/gdrive/My Drive/acc:0.041.hdf5
#
#
#
# 8
# Epoch 1/1
# 254631/254631 [==============================] - 393s 2ms/step - loss: 4.1718 - acc: 0.0495
#
# Epoch 00001: acc improved from 0.04076 to 0.04946, saving model to /content/gdrive/My Drive/acc:0.049.hdf5
#
#
#
# 9
# Epoch 1/1
# 254631/254631 [==============================] - 395s 2ms/step - loss: 4.0830 - acc: 0.0633
#
# Epoch 00001: acc improved from 0.04946 to 0.06329, saving model to /content/gdrive/My Drive/acc:0.063.hdf5
#
#
#
# 10
# Epoch 1/1
# 254631/254631 [==============================] - 398s 2ms/step - loss: 3.9378 - acc: 0.0832
#
# Epoch 00001: acc improved from 0.06329 to 0.08316, saving model to /content/gdrive/My Drive/acc:0.083.hdf5
# Seed:
# " B4E5C5A4D5B4G#4C59.0.4A4B-4B49.0.4C5C#5D5E-5E5F59.0.4E5A49.0.48.11.2.4G#4A4B-411.2.4B4C5C#5D5E-5E58.11.2.4D5G#48.11.2.49.0.4A4B4C59.0.4D5E-5E5F5F#5G5G#5A5B-5B5C6C#65.9D6E-6E69.0.4C6A5D611.2.4B5G#5A59.0F5E5D5C5B4A4A3G3F3E3D3C4C3C#4D4E-4E4F4F#4G4G#4A4B-4B4C5D4G2A2B4B-2B2C3 "
#
#
#
# 11
# Epoch 1/1
# 254631/254631 [==============================] - 393s 2ms/step - loss: 3.8091 - acc: 0.1004
#
# Epoch 00001: acc improved from 0.08316 to 0.10041, saving model to /content/gdrive/My Drive/acc:0.100.hdf5
#
#
#
# 12
# Epoch 1/1
# 254631/254631 [==============================] - 392s 2ms/step - loss: 3.7148 - acc: 0.1150
#
# Epoch 00001: acc improved from 0.10041 to 0.11501, saving model to /content/gdrive/My Drive/acc:0.115.hdf5
#
#
#
# 13
# Epoch 1/1
# 254631/254631 [==============================] - 392s 2ms/step - loss: 3.6344 - acc: 0.1279
#
# Epoch 00001: acc improved from 0.11501 to 0.12789, saving model to /content/gdrive/My Drive/acc:0.128.hdf5
#
#
#
# 14
# Epoch 1/1
# 254631/254631 [==============================] - 394s 2ms/step - loss: 3.5640 - acc: 0.1385
#
# Epoch 00001: acc improved from 0.12789 to 0.13851, saving model to /content/gdrive/My Drive/acc:0.139.hdf5
#
#
#
# 15
# Epoch 1/1
# 254631/254631 [==============================] - 396s 2ms/step - loss: 3.5023 - acc: 0.1500
#
# Epoch 00001: acc improved from 0.13851 to 0.15004, saving model to /content/gdrive/My Drive/acc:0.150.hdf5
#
#
#
# 16
# Epoch 1/1
# 254631/254631 [==============================] - 397s 2ms/step - loss: 3.4449 - acc: 0.1574
#
# Epoch 00001: acc improved from 0.15004 to 0.15736, saving model to /content/gdrive/My Drive/acc:0.157.hdf5
#
#
#
# 17
# Epoch 1/1
# 254631/254631 [==============================] - 395s 2ms/step - loss: 3.3906 - acc: 0.1689
#
# Epoch 00001: acc improved from 0.15736 to 0.16888, saving model to /content/gdrive/My Drive/acc:0.169.hdf5
#
#
#
# 18
# Epoch 1/1
# 254631/254631 [==============================] - 396s 2ms/step - loss: 3.3364 - acc: 0.1770
#
# Epoch 00001: acc improved from 0.16888 to 0.17698, saving model to /content/gdrive/My Drive/acc:0.177.hdf5
#
#
#
# 19
# Epoch 1/1
# 254631/254631 [==============================] - 394s 2ms/step - loss: 3.2933 - acc: 0.1847
#
# Epoch 00001: acc improved from 0.17698 to 0.18465, saving model to /content/gdrive/My Drive/acc:0.185.hdf5
#
#
#
# 20
# Epoch 1/1
# 254631/254631 [==============================] - 395s 2ms/step - loss: 3.2494 - acc: 0.1925
#
# Epoch 00001: acc improved from 0.18465 to 0.19246, saving model to /content/gdrive/My Drive/acc:0.192.hdf5
# Seed:
# " G2G#2A2B-2C#5F4C3B-2C#5F4G2G#2C5E-4B-2C3B-4C#4C#3E-3G#4C4F3E-3G4B-3C#3C3G#4C4B-2G#2A4E-4F#3B-4C5C#4F3C#5E-5C4E-3F5F#5B-3C#3F5E-5A3C3C#5C5B-3C#3B-4E-5F#4A2B-2C#5F4C3C#3C5E-4E-3F3B-4C#4F#3F3A4C4E-3C#3B-4C#4C3B-2D3G#2E-3F3G2G3G#3F2B-3B3E-2B-3G#3D2G3F3E-2E-3E3B-2 "
#
#
#
# 21
# Epoch 1/1
# 254631/254631 [==============================] - 398s 2ms/step - loss: 3.2108 - acc: 0.1984
#
# Epoch 00001: acc improved from 0.19246 to 0.19840, saving model to /content/gdrive/My Drive/acc:0.198.hdf5
#
#
#
# 22
# Epoch 1/1
# 254631/254631 [==============================] - 398s 2ms/step - loss: 3.1696 - acc: 0.2064
#
# Epoch 00001: acc improved from 0.19840 to 0.20643, saving model to /content/gdrive/My Drive/acc:0.206.hdf5
#
#
#
# 23
# Epoch 1/1
# 195968/254631 [======================>.......] - ETA: 1:31 - loss: 3.1261 - acc: 0.2136

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.235.hdf5') #reload the weights when the runtime stops
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
Epoch = 24 #similarly....
while Epoch <= 30:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 24
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 254631/254631 [==============================] - 397s 2ms/step - loss: 2.9945 - acc: 0.2396
#
# Epoch 00001: acc improved from -inf to 0.23955, saving model to /content/gdrive/My Drive/acc:0.240.hdf5
#
#
#
# 25
# Epoch 1/1
# 254631/254631 [==============================] - 400s 2ms/step - loss: 2.9649 - acc: 0.2467
#
# Epoch 00001: acc improved from 0.23955 to 0.24674, saving model to /content/gdrive/My Drive/acc:0.247.hdf5
#
#
#
# 26
# Epoch 1/1
# 254631/254631 [==============================] - 403s 2ms/step - loss: 2.9442 - acc: 0.2484
#
# Epoch 00001: acc improved from 0.24674 to 0.24841, saving model to /content/gdrive/My Drive/acc:0.248.hdf5
#
#
#
# 27
# Epoch 1/1
# 254631/254631 [==============================] - 405s 2ms/step - loss: 2.9202 - acc: 0.2557
#
# Epoch 00001: acc improved from 0.24841 to 0.25569, saving model to /content/gdrive/My Drive/acc:0.256.hdf5
#
#
#
# 28
# Epoch 1/1
# 254631/254631 [==============================] - 407s 2ms/step - loss: 2.8953 - acc: 0.2596
#
# Epoch 00001: acc improved from 0.25569 to 0.25962, saving model to /content/gdrive/My Drive/acc:0.260.hdf5
#
#
#
# 29
# Epoch 1/1
# 254631/254631 [==============================] - 407s 2ms/step - loss: 2.8746 - acc: 0.2645
#
# Epoch 00001: acc improved from 0.25962 to 0.26454, saving model to /content/gdrive/My Drive/acc:0.265.hdf5
#
#
#
# 30
# Epoch 1/1
# 254631/254631 [==============================] - 407s 2ms/step - loss: 2.8557 - acc: 0.2682
#
# Epoch 00001: acc improved from 0.26454 to 0.26817, saving model to /content/gdrive/My Drive/acc:0.268.hdf5
# Seed:
# " B4B2D5G3E-5C3B2C3C6B2C3E2C3F2C3E3G2C3F3F2C3G2C3G#2C3F#3F#2C3G2C3A2C3G3G2E-3C3E-3G2E-3F3G2G3F3G3D3F3G3F3B2G3F3G3D3F3G3F3G2G3F3E3D3F3E-3C3C2G3C4G3C4E-4G4E-4G4C5E-5G5C6E-2C3F2C3C4G2C3E2C3F2C3E3G2C3F3F2C3G2C3C4G#2C3F#3 "

# %% [markdown]
# ### And so on and on...

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.268.hdf5')

# %%
Epoch = 31
while Epoch <= 100:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 31
# Epoch 1/1
# 254631/254631 [==============================] - 406s 2ms/step - loss: 2.8330 - acc: 0.2734
#
# Epoch 00001: acc improved from 0.26817 to 0.27335, saving model to /content/gdrive/My Drive/acc:0.273.hdf5
#
#
#
# 32
# Epoch 1/1
# 254631/254631 [==============================] - 392s 2ms/step - loss: 2.8172 - acc: 0.2761
#
# Epoch 00001: acc improved from 0.27335 to 0.27607, saving model to /content/gdrive/My Drive/acc:0.276.hdf5
#
#
#
# 33
# Epoch 1/1
# 254631/254631 [==============================] - 388s 2ms/step - loss: 2.7989 - acc: 0.2815
#
# Epoch 00001: acc improved from 0.27607 to 0.28146, saving model to /content/gdrive/My Drive/acc:0.281.hdf5
#
#
#
# 34
# Epoch 1/1
# 254631/254631 [==============================] - 387s 2ms/step - loss: 2.7772 - acc: 0.2858
#
# Epoch 00001: acc improved from 0.28146 to 0.28583, saving model to /content/gdrive/My Drive/acc:0.286.hdf5
#
#
#
# 35
# Epoch 1/1
# 254631/254631 [==============================] - 386s 2ms/step - loss: 2.7646 - acc: 0.2883
#
# Epoch 00001: acc improved from 0.28583 to 0.28827, saving model to /content/gdrive/My Drive/acc:0.288.hdf5
#
#
#
# 36
# Epoch 1/1
# 254631/254631 [==============================] - 386s 2ms/step - loss: 2.7447 - acc: 0.2924
#
# Epoch 00001: acc improved from 0.28827 to 0.29240, saving model to /content/gdrive/My Drive/acc:0.292.hdf5
#
#
#
# 37
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.7288 - acc: 0.2965
#
# Epoch 00001: acc improved from 0.29240 to 0.29646, saving model to /content/gdrive/My Drive/acc:0.296.hdf5
#
#
#
# 38
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.7177 - acc: 0.2984
#
# Epoch 00001: acc improved from 0.29646 to 0.29836, saving model to /content/gdrive/My Drive/acc:0.298.hdf5
#
#
#
# 39
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.7024 - acc: 0.3027
#
# Epoch 00001: acc improved from 0.29836 to 0.30271, saving model to /content/gdrive/My Drive/acc:0.303.hdf5
#
#
#
# 40
# Epoch 1/1
# 254631/254631 [==============================] - 384s 2ms/step - loss: 2.6909 - acc: 0.3044
#
# Epoch 00001: acc improved from 0.30271 to 0.30441, saving model to /content/gdrive/My Drive/acc:0.304.hdf5
# Seed:
# " F3C4F5F4B-3G3C4E5B-3G3F5E5D5C4E5E4B-3G3C4F5F4B-3G3C4G5G4B-3G3C4A5A4A3F3C4B-5B-4G3E3B5B4C4B5B4G3E3C6C5C4B5B4G3E3C6C4D6G3E3C6C4G5G3E3C4G3E3C4G3E3A5C4G5A5G3E3G5B-5A5C4B-5A5A3F3C6C4B511.0A3F3D60.5F5C4F5F4B-3G3C4E5B-3G3 "
#
#
#
# 41
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.6751 - acc: 0.3075
#
# Epoch 00001: acc improved from 0.30441 to 0.30754, saving model to /content/gdrive/My Drive/acc:0.308.hdf5
#
#
#
# 42
# Epoch 1/1
# 254631/254631 [==============================] - 382s 1ms/step - loss: 2.6585 - acc: 0.3121
#
# Epoch 00001: acc improved from 0.30754 to 0.31213, saving model to /content/gdrive/My Drive/acc:0.312.hdf5
#
#
#
# 43
# Epoch 1/1
# 254631/254631 [==============================] - 382s 2ms/step - loss: 2.6505 - acc: 0.3136
#
# Epoch 00001: acc improved from 0.31213 to 0.31358, saving model to /content/gdrive/My Drive/acc:0.314.hdf5
#
#
#
# 44
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.6401 - acc: 0.3167
#
# Epoch 00001: acc improved from 0.31358 to 0.31667, saving model to /content/gdrive/My Drive/acc:0.317.hdf5
#
#
#
# 45
# Epoch 1/1
# 254631/254631 [==============================] - 388s 2ms/step - loss: 2.6299 - acc: 0.3187
#
# Epoch 00001: acc improved from 0.31667 to 0.31874, saving model to /content/gdrive/My Drive/acc:0.319.hdf5
#
#
#
# 46
# Epoch 1/1
# 254631/254631 [==============================] - 394s 2ms/step - loss: 2.6162 - acc: 0.3212
#
# Epoch 00001: acc improved from 0.31874 to 0.32118, saving model to /content/gdrive/My Drive/acc:0.321.hdf5
#
#
#
# 47
# Epoch 1/1
# 254631/254631 [==============================] - 389s 2ms/step - loss: 2.6044 - acc: 0.3252
#
# Epoch 00001: acc improved from 0.32118 to 0.32523, saving model to /content/gdrive/My Drive/acc:0.325.hdf5
#
#
#
# 48
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5955 - acc: 0.3269
#
# Epoch 00001: acc improved from 0.32523 to 0.32691, saving model to /content/gdrive/My Drive/acc:0.327.hdf5
#
#
#
# 49
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5822 - acc: 0.3299
#
# Epoch 00001: acc improved from 0.32691 to 0.32986, saving model to /content/gdrive/My Drive/acc:0.330.hdf5
#
#
#
# 50
# Epoch 1/1
# 254631/254631 [==============================] - 384s 2ms/step - loss: 2.5729 - acc: 0.3310
#
# Epoch 00001: acc improved from 0.32986 to 0.33104, saving model to /content/gdrive/My Drive/acc:0.331.hdf5
# Seed:
# " E-4C#45.88.1G#30.36.8G#30.63.8G#30.3F#2G#41.55G#41.51G#40.33F#4F48.15E-46.10F#28.0.3G#2C#41.5F#2F2E-2C#2G#31.5C#2B-31.6F#1G#31.5G#1B-31.3G1G#31.3G#1G#30.3F#2F#3F2F3E-2E-3C#2C#3C2C#45.8C#2C#46.10F#2C#45.8G#2C#44.7A2C#43.6G#2C43.6G#1C#41.5C#2G#3G#2F3F2E-3E-2G#31.5C#2B-31.6F#1G#31.5G#1B-3 "
#
#
#
# 51
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5645 - acc: 0.3340
#
# Epoch 00001: acc improved from 0.33104 to 0.33397, saving model to /content/gdrive/My Drive/acc:0.334.hdf5
#
#
#
# 52
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5550 - acc: 0.3359
#
# Epoch 00001: acc improved from 0.33397 to 0.33586, saving model to /content/gdrive/My Drive/acc:0.336.hdf5
#
#
#
# 53
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5416 - acc: 0.3381
#
# Epoch 00001: acc improved from 0.33586 to 0.33811, saving model to /content/gdrive/My Drive/acc:0.338.hdf5
#
#
#
# 54
# Epoch 1/1
# 254631/254631 [==============================] - 384s 2ms/step - loss: 2.5391 - acc: 0.3399
#
# Epoch 00001: acc improved from 0.33811 to 0.33988, saving model to /content/gdrive/My Drive/acc:0.340.hdf5
#
#
#
# 55
# Epoch 1/1
# 254631/254631 [==============================] - 384s 2ms/step - loss: 2.5297 - acc: 0.3419
#
# Epoch 00001: acc improved from 0.33988 to 0.34188, saving model to /content/gdrive/My Drive/acc:0.342.hdf5
#
#
#
# 56
# Epoch 1/1
# 254631/254631 [==============================] - 384s 2ms/step - loss: 2.5223 - acc: 0.3452
#
# Epoch 00001: acc improved from 0.34188 to 0.34521, saving model to /content/gdrive/My Drive/acc:0.345.hdf5
#
#
#
# 57
# Epoch 1/1
# 254631/254631 [==============================] - 383s 2ms/step - loss: 2.5126 - acc: 0.3465
#
# Epoch 00001: acc improved from 0.34521 to 0.34646, saving model to /content/gdrive/My Drive/acc:0.346.hdf5
#
#
#
# 58
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.5066 - acc: 0.3482
#
# Epoch 00001: acc improved from 0.34646 to 0.34817, saving model to /content/gdrive/My Drive/acc:0.348.hdf5
#
#
#
# 59
# Epoch 1/1
# 135040/254631 [==============>...............] - ETA: 3:00 - loss: 2.4843 - acc: 0.3531Buffered data was truncated after reaching the output size limit.

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.351.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
Epoch = 61
while Epoch <= 100:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 61
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 254631/254631 [==============================] - 475s 2ms/step - loss: 2.4938 - acc: 0.3499
#
# Epoch 00001: acc improved from -inf to 0.34995, saving model to /content/gdrive/My Drive/acc:0.350.hdf5
#
#
#
# 62
# Epoch 1/1
# 254631/254631 [==============================] - 464s 2ms/step - loss: 2.4758 - acc: 0.3553
#
# Epoch 00001: acc improved from 0.34995 to 0.35525, saving model to /content/gdrive/My Drive/acc:0.355.hdf5
#
#
#
# 63
# Epoch 1/1
# 254631/254631 [==============================] - 456s 2ms/step - loss: 2.4695 - acc: 0.3568
#
# Epoch 00001: acc improved from 0.35525 to 0.35679, saving model to /content/gdrive/My Drive/acc:0.357.hdf5
#
#
#
# 64
# Epoch 1/1
# 254631/254631 [==============================] - 454s 2ms/step - loss: 2.4625 - acc: 0.3579
#
# Epoch 00001: acc improved from 0.35679 to 0.35792, saving model to /content/gdrive/My Drive/acc:0.358.hdf5
#
#
#
# 65
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4558 - acc: 0.3592
#
# Epoch 00001: acc improved from 0.35792 to 0.35918, saving model to /content/gdrive/My Drive/acc:0.359.hdf5
#
#
#
# 66
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4509 - acc: 0.3623
#
# Epoch 00001: acc improved from 0.35918 to 0.36235, saving model to /content/gdrive/My Drive/acc:0.362.hdf5
#
#
#
# 67
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.4443 - acc: 0.3627
#
# Epoch 00001: acc improved from 0.36235 to 0.36274, saving model to /content/gdrive/My Drive/acc:0.363.hdf5
#
#
#
# 68
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.4387 - acc: 0.3642
#
# Epoch 00001: acc improved from 0.36274 to 0.36418, saving model to /content/gdrive/My Drive/acc:0.364.hdf5
#
#
#
# 69
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.4358 - acc: 0.3644
#
# Epoch 00001: acc improved from 0.36418 to 0.36441, saving model to /content/gdrive/My Drive/acc:0.364.hdf5
#
#
#
# 70
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4224 - acc: 0.3678
#
# Epoch 00001: acc improved from 0.36441 to 0.36777, saving model to /content/gdrive/My Drive/acc:0.368.hdf5
# Seed:
# " A40.3B-22.5A43.6B-20.3B-410.2B-20.32.50.310.20.32.53.65.83.62.55.83.62.5A40.3B-22.5A43.6B-20.3B-42.5B-3B-2C4D4C#4D4B-3D4E4F4E4F4D4F4G4G#4G4G#4F4G#4B4C5B4D5C5B-4G#4G4F4E4F4G4F4G#4F4C4D4E-4E-27.10E-37.10E-37.10E-37.10E-37.10E-3G47.10E-3G#4G47.10E-3F4G47.10E-3G#4A47.10E-37.10E-3 "
#
#
#
# 71
# Epoch 1/1
# 254631/254631 [==============================] - 453s 2ms/step - loss: 2.4232 - acc: 0.3683
#
# Epoch 00001: acc improved from 0.36777 to 0.36834, saving model to /content/gdrive/My Drive/acc:0.368.hdf5
#
#
#
# 72
# Epoch 1/1
# 254631/254631 [==============================] - 454s 2ms/step - loss: 2.4144 - acc: 0.3690
#
# Epoch 00001: acc improved from 0.36834 to 0.36903, saving model to /content/gdrive/My Drive/acc:0.369.hdf5
#
#
#
# 73
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4062 - acc: 0.3721
#
# Epoch 00001: acc improved from 0.36903 to 0.37211, saving model to /content/gdrive/My Drive/acc:0.372.hdf5
#
#
#
# 74
# Epoch 1/1
# 254631/254631 [==============================] - 456s 2ms/step - loss: 2.4056 - acc: 0.3717
#
# Epoch 00001: acc did not improve from 0.37211
#
#
#
# 75
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4047 - acc: 0.3728
#
# Epoch 00001: acc improved from 0.37211 to 0.37282, saving model to /content/gdrive/My Drive/acc:0.373.hdf5
#
#
#
# 76
# Epoch 1/1
# 254631/254631 [==============================] - 452s 2ms/step - loss: 2.4049 - acc: 0.3738
#
# Epoch 00001: acc improved from 0.37282 to 0.37385, saving model to /content/gdrive/My Drive/acc:0.374.hdf5
#
#
#
# 77
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3980 - acc: 0.3747
#
# Epoch 00001: acc improved from 0.37385 to 0.37468, saving model to /content/gdrive/My Drive/acc:0.375.hdf5
#
#
#
# 78
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3903 - acc: 0.3763
#
# Epoch 00001: acc improved from 0.37468 to 0.37634, saving model to /content/gdrive/My Drive/acc:0.376.hdf5
#
#
#
# 79
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3852 - acc: 0.3776
#
# Epoch 00001: acc improved from 0.37634 to 0.37759, saving model to /content/gdrive/My Drive/acc:0.378.hdf5
#
#
#
# 80
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3801 - acc: 0.3782
#
# Epoch 00001: acc improved from 0.37759 to 0.37815, saving model to /content/gdrive/My Drive/acc:0.378.hdf5
# Seed:
# " 8.0.38.0.3E-53.7.103.7.10E-53.7.10D5E-53.7.10F53.7.10E-53.7.10E-5C#51.5.85.8C#4C#51.5.8C#5C58.0.38.0.3C58.0.3C5B-4C#510.1.5C5E-510.1.5C#5C510.1.5B-4G#40.3B-4G#4G4G#4C51.3B-41.3B-48.18.1C58.1G#4G#3C4E-4E-58.08.0E-58.0G5G#58.0.3B58.0.3C68.0.3D6E-63.7.103.7.10E-63.7.10D6E-63.7.10F63.7.10E-63.7.10E-6C#61.5.81.5.8C#61.5.8C#6C69.0.39.0.3C69.0.3C6B-5C#610.1.5C6E-6 "
#
#
#
# 81
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3746 - acc: 0.3791
#
# Epoch 00001: acc improved from 0.37815 to 0.37906, saving model to /content/gdrive/My Drive/acc:0.379.hdf5
#
#
#
# 82
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3653 - acc: 0.3820
#
# Epoch 00001: acc improved from 0.37906 to 0.38197, saving model to /content/gdrive/My Drive/acc:0.382.hdf5
#
#
#
# 83
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3582 - acc: 0.3839
#
# Epoch 00001: acc improved from 0.38197 to 0.38385, saving model to /content/gdrive/My Drive/acc:0.384.hdf5
#
#
#
# 84
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3565 - acc: 0.3835
#
# Epoch 00001: acc did not improve from 0.38385
#
#
#
# 85
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3531 - acc: 0.3863
#
# Epoch 00001: acc improved from 0.38385 to 0.38629, saving model to /content/gdrive/My Drive/acc:0.386.hdf5
#
#
#
# 86
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3475 - acc: 0.3860
#
# Epoch 00001: acc did not improve from 0.38629
#
#
#
# 87
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3446 - acc: 0.3879
#
# Epoch 00001: acc improved from 0.38629 to 0.38792, saving model to /content/gdrive/My Drive/acc:0.388.hdf5
#
#
#
# 88
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3407 - acc: 0.3880
#
# Epoch 00001: acc improved from 0.38792 to 0.38800, saving model to /content/gdrive/My Drive/acc:0.388.hdf5
#
#
#
# 89
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3350 - acc: 0.3907
#
# Epoch 00001: acc improved from 0.38800 to 0.39066, saving model to /content/gdrive/My Drive/acc:0.391.hdf5
#
#
#
# 90
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3313 - acc: 0.3908
#
# Epoch 00001: acc improved from 0.39066 to 0.39080, saving model to /content/gdrive/My Drive/acc:0.391.hdf5
# Seed:
# " C#4D3B57.11.22.7B57.11.22.7D3C60.6D4D3A50.6D4G3G2G5D5B4G4G3G57.10.110.1.4G3F57.10.110.1.4G3E57.10.110.1.4G3E57.10.010.0.4A3A3C60.50.5G3B-510.0.40.4F3A55.9.00.5F3A51.5.91.5F3A52.5.92.5F3G51.4.7.1010.1.4F3F52.5.99.2F2E51.4.7.107.10F2D52.5.95.9F#2C53.6.96.9G2B47.11.2G3F3E3D3C3C54.7C4C3B45.7D4C3C54.7C4C3D5 "
#
#
#
# 91
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3279 - acc: 0.3919
#
# Epoch 00001: acc improved from 0.39080 to 0.39194, saving model to /content/gdrive/My Drive/acc:0.392.hdf5
#
#
#
# 92
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3228 - acc: 0.3926
#
# Epoch 00001: acc improved from 0.39194 to 0.39263, saving model to /content/gdrive/My Drive/acc:0.393.hdf5
#
#
#
# 93
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3242 - acc: 0.3937
#
# Epoch 00001: acc improved from 0.39263 to 0.39366, saving model to /content/gdrive/My Drive/acc:0.394.hdf5
#
#
#
# 94
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3201 - acc: 0.3936
#
# Epoch 00001: acc did not improve from 0.39366
#
#
#
# 95
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3160 - acc: 0.3943
#
# Epoch 00001: acc improved from 0.39366 to 0.39429, saving model to /content/gdrive/My Drive/acc:0.394.hdf5
#
#
#
# 96
# Epoch 1/1
# 254631/254631 [==============================] - 451s 2ms/step - loss: 2.3081 - acc: 0.3967
#
# Epoch 00001: acc improved from 0.39429 to 0.39667, saving model to /content/gdrive/My Drive/acc:0.397.hdf5
#
#
#
# 97
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.3065 - acc: 0.3974
#
# Epoch 00001: acc improved from 0.39667 to 0.39738, saving model to /content/gdrive/My Drive/acc:0.397.hdf5
#
#
#
# 98
# Epoch 1/1
# 254631/254631 [==============================] - 450s 2ms/step - loss: 2.2990 - acc: 0.3991
#
# Epoch 00001: acc improved from 0.39738 to 0.39915, saving model to /content/gdrive/My Drive/acc:0.399.hdf5
#
#
#
# 99
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.3031 - acc: 0.3985
#
# Epoch 00001: acc did not improve from 0.39915
#
#
#
# 100
# Epoch 1/1
# 254631/254631 [==============================] - 449s 2ms/step - loss: 2.2994 - acc: 0.3993
#
# Epoch 00001: acc improved from 0.39915 to 0.39933, saving model to /content/gdrive/My Drive/acc:0.399.hdf5
# Seed:
# " A5G5F5E5D5E4C5D4E4B4F4D4G4C5E4D4G3C4F#3G3D57.11A3G3F3E57.0E3D3C3G52.7B2F57.11G2E57.0C3D57.11G2D5C#5D5E-5D5F#5E5C5F#5G5B-4A4G5F#5G4G5A53.6D4A5G5C4A5B-5B-3A3B-5A5G3B-5C#6109C#6C67C#6D664D6C#62D6B52.77C64.90A50.62G511.27G5F#5 "

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.401.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
Epoch = 101
while True:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 101
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 254631/254631 [==============================] - 398s 2ms/step - loss: 2.2949 - acc: 0.4006
#
# Epoch 00001: acc improved from -inf to 0.40060, saving model to /content/gdrive/My Drive/acc:0.401.hdf5
#
#
#
# 102
# Epoch 1/1
# 254631/254631 [==============================] - 390s 2ms/step - loss: 2.2841 - acc: 0.4021
#
# Epoch 00001: acc improved from 0.40060 to 0.40208, saving model to /content/gdrive/My Drive/acc:0.402.hdf5
#
#
#
# 103
# Epoch 1/1
# 254631/254631 [==============================] - 390s 2ms/step - loss: 2.2863 - acc: 0.4021
#
# Epoch 00001: acc improved from 0.40208 to 0.40214, saving model to /content/gdrive/My Drive/acc:0.402.hdf5
#
#
#
# 104
# Epoch 1/1
# 254631/254631 [==============================] - 390s 2ms/step - loss: 2.2788 - acc: 0.4032
#
# Epoch 00001: acc improved from 0.40214 to 0.40324, saving model to /content/gdrive/My Drive/acc:0.403.hdf5
#
#
#
# 105
# Epoch 1/1
# 254631/254631 [==============================] - 394s 2ms/step - loss: 2.2740 - acc: 0.4047
#
# Epoch 00001: acc improved from 0.40324 to 0.40469, saving model to /content/gdrive/My Drive/acc:0.405.hdf5
#
#
#
# 106
# Epoch 1/1
# 254631/254631 [==============================] - 392s 2ms/step - loss: 2.2749 - acc: 0.4056
#
# Epoch 00001: acc improved from 0.40469 to 0.40557, saving model to /content/gdrive/My Drive/acc:0.406.hdf5
#
#
#
# 107
# Epoch 1/1
# 254631/254631 [==============================] - 385s 2ms/step - loss: 2.2674 - acc: 0.4067
#
# Epoch 00001: acc improved from 0.40557 to 0.40669, saving model to /content/gdrive/My Drive/acc:0.407.hdf5
#
#
#
# 108
# Epoch 1/1
# 254631/254631 [==============================] - 393s 2ms/step - loss: 2.2661 - acc: 0.4077
#
# Epoch 00001: acc improved from 0.40669 to 0.40771, saving model to /content/gdrive/My Drive/acc:0.408.hdf5
#
#
#
# 109
# Epoch 1/1
#  67072/254631 [======>.......................] - ETA: 4:50 - loss: 2.2422 - acc: 0.4120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-ff4c44a029bc> in <module>()
#       3     print('\n\n')
#       4     print(Epoch)
# ----> 5     model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
#       6     if Epoch % 10 == 0:
#       7       generate_notes(model, Epoch)
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1176                                         steps_per_epoch=steps_per_epoch,
#    1177                                         validation_steps=validation_steps,
# -> 1178                                         validation_freq=validation_freq)
#    1179
#    1180     def evaluate(self,
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     202                     ins_batch[i] = ins_batch[i].toarray()
#     203
# --> 204                 outs = fit_function(ins_batch)
#     205                 outs = to_list(outs)
#     206                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2977                     return self._legacy_call(inputs)
#    2978
# -> 2979             return self._call(inputs)
#    2980         else:
#    2981             if py_any(is_tensor(x) for x in inputs):
#
# /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2935             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2936         else:
# -> 2937             fetched = self._callable_fn(*array_vals)
#    2938         return fetched[:len(self.outputs)]
#    2939
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.408.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
Epoch = 108
while True:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 108
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 254631/254631 [==============================] - 523s 2ms/step - loss: 2.2740 - acc: 0.4066
#
# Epoch 00001: acc improved from -inf to 0.40659, saving model to /content/gdrive/My Drive/acc:0.407.hdf5
#
#
#
# 109
# Epoch 1/1
# 254631/254631 [==============================] - 511s 2ms/step - loss: 2.2608 - acc: 0.4086
#
# Epoch 00001: acc improved from 0.40659 to 0.40859, saving model to /content/gdrive/My Drive/acc:0.409.hdf5
#
#
#
# 110
# Epoch 1/1
# 254631/254631 [==============================] - 499s 2ms/step - loss: 2.2568 - acc: 0.4109
#
# Epoch 00001: acc improved from 0.40859 to 0.41090, saving model to /content/gdrive/My Drive/acc:0.411.hdf5
# Seed:
# " F#4B-3F#3F#5F#4F#56.116.11E-3F#56.10.14.10C#3F#511.3.611.3B2G5G41.4.8E2G#5G#4F#2B-3E3B1B311.3B311.3B311.3E2B38.11B38.11B38.11E-2B36.11B36.11B36.11G#2B311.4B311.4B311.4F#2B311.3B311.3B311.3E2B310.11.1B310.11.1B310.11.1E-2B3B2B3B2B3B2B1B39.11.3B39.11.3B39.11.3B4E28.11E38.11E38.11E3E5E48.11E38.11E38.11E3C59.0 "
#
#
#
# 111
# Epoch 1/1
# 254631/254631 [==============================] - 492s 2ms/step - loss: 2.2546 - acc: 0.4105
#
# Epoch 00001: acc did not improve from 0.41090
#
#
#
# 112
# Epoch 1/1
#  67968/254631 [=======>......................] - ETA: 6:09 - loss: 2.2275 - acc: 0.4138

# %%
model.load_weights('/content/gdrive/My Drive/acc:0.411.hdf5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
Epoch = 112
while True:
    print('\n\n')
    print(Epoch)
    model.fit(X, y, epochs=1,verbose=1, batch_size=128, callbacks=callbacks_list)
    if Epoch % 10 == 0:
      generate_notes(model, Epoch)
    Epoch+=1
# Out:
# 112
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/1
# 254631/254631 [==============================] - 407s 2ms/step - loss: 2.2651 - acc: 0.4093
#
# Epoch 00001: acc improved from -inf to 0.40933, saving model to /content/gdrive/My Drive/acc:0.409.hdf5
#
#
#
# 113
# Epoch 1/1
# 254631/254631 [==============================] - 402s 2ms/step - loss: 2.2464 - acc: 0.4118
#
# Epoch 00001: acc improved from 0.40933 to 0.41180, saving model to /content/gdrive/My Drive/acc:0.412.hdf5
#
#
#
# 114
# Epoch 1/1
# 254631/254631 [==============================] - 399s 2ms/step - loss: 2.2468 - acc: 0.4124
#
# Epoch 00001: acc improved from 0.41180 to 0.41240, saving model to /content/gdrive/My Drive/acc:0.412.hdf5
#
#
#
# 115
# Epoch 1/1
# 254631/254631 [==============================] - 395s 2ms/step - loss: 2.2431 - acc: 0.4135
#
# Epoch 00001: acc improved from 0.41240 to 0.41345, saving model to /content/gdrive/My Drive/acc:0.413.hdf5
#
#
#
# 116
# Epoch 1/1
# 125056/254631 [=============>................] - ETA: 3:19 - loss: 2.2099 - acc: 0.4197

# %% [markdown]
# ### I feel like it's a pretty good spot to stop here.
